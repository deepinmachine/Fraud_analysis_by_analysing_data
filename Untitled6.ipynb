# %% [markdown]
# <a href="https://colab.research.google.com/github/deepinmachine/Fraud_analysis_by_analysing_data/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
company_order_x=pd.read_excel('/content/Company X - Order Report.xlsx')

# %%
company_order_x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ExternOrderNo         400 non-null    int64
#  1   SKU                   400 non-null    object
#  2   Order Qty             400 non-null    int64
#  3   Payment Mode          400 non-null    object
#  4   Item Price(Per Qty.)  400 non-null    int64
# dtypes: int64(3), object(2)
# memory usage: 15.8+ KB

# %%
company_sku=pd.read_excel('/content/Company X - SKU Master.xlsx')
company_sku.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66 entries, 0 to 65
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   SKU         66 non-null     object
#  1   Weight (g)  66 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 1.2+ KB

# %%
company_order_x['ExternOrderNo'].value_counts().reset_index()
# Out:
#           index  ExternOrderNo
# 0    2001809820             14
# 1    2001827036              8
# 2    2001812854              8
# 3    2001821185              8
# 4    2001817093              8
# ..          ...            ...
# 119  2001814580              1
# 120  2001820690              1
# 121  2001806686              1
# 122  2001806823              1
# 123  2001807012              1
#
# [124 rows x 2 columns]

# %% [markdown]
# #THERE  ARE 124 DIFFERENT ORDERS BASED ON EXTERNAL ID NO

# %%
courier_invoice=pd.read_excel('/content/Courier Company - Invoice.xlsx')
courier_invoice.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124 entries, 0 to 123
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   AWB Code              124 non-null    int64
#  1   Order ID              124 non-null    int64
#  2   Charged Weight        124 non-null    float64
#  3   Warehouse Pincode     124 non-null    int64
#  4   Customer Pincode      124 non-null    int64
#  5   Zone                  124 non-null    object
#  6   Type of Shipment      124 non-null    object
#  7   Billing Amount (Rs.)  124 non-null    float64
# dtypes: float64(2), int64(4), object(2)
# memory usage: 7.9+ KB

# %% [markdown]
# THERE ARE 124 DIFFERNT ORDER BASED ON COURIER DETAILS AND ID

# %%
sku_master=pd.read_excel('/content/Company X - SKU Master.xlsx')
sku_master.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66 entries, 0 to 65
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   SKU         66 non-null     object
#  1   Weight (g)  66 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 1.2+ KB

# %%
merged_data = company_order_x.merge(sku_master, on='SKU', how='left')

# %%
merged_data
# Out:
#      ExternOrderNo            SKU  Order Qty Payment Mode  \
# 0       2001827036  8904223818706          1          COD
# 1       2001827036  8904223819093          1          COD
# 2       2001827036  8904223819109          1          COD
# 3       2001827036  8904223818430          1          COD
# 4       2001827036  8904223819277          1          COD
# ..             ...            ...        ...          ...
# 396     2001806229  8904223818942          1          COD
# 397     2001806229  8904223818850          1          COD
# 398     2001806226  8904223818850          2          COD
# 399     2001806210  8904223816214          1          COD
# 400     2001806210  8904223818874          1          COD
#
#      Item Price(Per Qty.)  Weight (g)
# 0                     233         127
# 1                     233         150
# 2                     233         100
# 3                     470         165
# 4                     233         350
# ...

# %%
#we will calculate the total waeight and price of a order by multiplying Qty with item price and weight
# then we will group by by each order id to extract the price ans weight of each product
merged_data['total weight']=merged_data['Order Qty']*merged_data['Weight (g)']
merged_data['total_price_x']=merged_data['Order Qty']*merged_data['Item Price(Per Qty.)']

# %%
#grouping data based on order id
grouped_data=merged_data.groupby('ExternOrderNo').agg({'total weight':'sum','total_price_x':'sum'}).reset_index()
grouped_data['total_weight(kg)_x']=grouped_data['total weight']/1000
grouped_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124 entries, 0 to 123
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ExternOrderNo       124 non-null    int64
#  1   total weight        124 non-null    int64
#  2   total_price_x       124 non-null    int64
#  3   total_weight(kg)_x  124 non-null    float64
# dtypes: float64(1), int64(3)
# memory usage: 4.0 KB

# %%
grouped_data.drop('total weight', axis=1,inplace=True)
grouped_data.rename(columns={'ExternOrderNo':'Order ID'},inplace=True)

# %%
grouped_data.describe()
# Out:
#            Order ID  total_price_x  total_weight(kg)_x
# count  1.240000e+02     124.000000          124.000000
# mean   2.001811e+09    5197.943548            0.713516
# std    5.167329e+03   11859.883105            0.499546
# min    2.001806e+09     233.000000            0.065000
# 25%    2.001807e+09    1082.000000            0.500000
# 50%    2.001809e+09    1399.000000            0.556000
# 75%    2.001812e+09    2880.250000            0.832500
# max    2.001827e+09   64922.000000            3.080000

# %%
#now we will go for to differentiatie between zones courier and company
# 1. we will join pinocde zones data to coutier invoice this will create a new column zones_x
pincode=pd.read_excel('/content/Company X - Pincode Zones.xlsx')
courier_invoice=pd.read_excel('/content/Courier Company - Invoice.xlsx')
pincode.rename(columns={'Zone':'zone_x'},inplace=True)

# %%
pincode.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124 entries, 0 to 123
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Warehouse Pincode  124 non-null    int64
#  1   Customer Pincode   124 non-null    int64
#  2   zone_x             124 non-null    object
# dtypes: int64(2), object(1)
# memory usage: 3.0+ KB

# %%
courier_invoice.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124 entries, 0 to 123
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   AWB Code              124 non-null    int64
#  1   Order ID              124 non-null    int64
#  2   Charged Weight        124 non-null    float64
#  3   Warehouse Pincode     124 non-null    int64
#  4   Customer Pincode      124 non-null    int64
#  5   Zone                  124 non-null    object
#  6   Type of Shipment      124 non-null    object
#  7   Billing Amount (Rs.)  124 non-null    float64
# dtypes: float64(2), int64(4), object(2)
# memory usage: 7.9+ KB

# %% [markdown]
# it is necessary to delete all the duplicates from the pincode table else it will create the large number of rowa

# %%
pincode=pincode.drop_duplicates()

# %%
#joining two tables
new_courier_invoice=courier_invoice.merge(pincode,on=['Customer Pincode'],how='left')
new_courier_invoice.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 124 entries, 0 to 123
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   AWB Code              124 non-null    int64
#  1   Order ID              124 non-null    int64
#  2   Charged Weight        124 non-null    float64
#  3   Warehouse Pincode_x   124 non-null    int64
#  4   Customer Pincode      124 non-null    int64
#  5   Zone                  124 non-null    object
#  6   Type of Shipment      124 non-null    object
#  7   Billing Amount (Rs.)  124 non-null    float64
#  8   Warehouse Pincode_y   124 non-null    int64
#  9   zone_x                124 non-null    object
# dtypes: float64(2), int64(5), object(3)
# memory usage: 10.7+ KB

# %%
#now we have price of item and weight of item and zone of item as per company x
#now we will have to find price of item as per the company x
# now we will have to find price according to weight slabs
#we will joins weight slabs to the new_courier_invoice on zone_x column so that we will have rates as per zone

# %%
courier_rates=pd.read_excel('/content/Courier Company - Rates.xlsx')
courier_rates['Zone']=courier_rates['Zone'].str.lower()
courier_rates
# Out:
#   Zone  Weight Slabs  Forward Fixed Charge  \
# 0    a          0.25                  29.5
# 1    b          0.50                  33.0
# 2    c          0.75                  40.1
# 3    d          1.25                  45.4
# 4    e          1.50                  56.6
#
#    Forward Additional Weight Slab Charge  RTO Fixed Charge  \
# 0                                   23.6              13.6
# 1                                   28.3              20.5
# 2                                   38.9              31.9
# 3                                   44.8              41.3
# 4                                   55.5              50.7
#
#    RTO Additional Weight Slab Charge
# 0                               23.6
# 1                               28.3
# 2                               38.9
# 3                               44.8
# 4                               55.5

# %%
new_data=new_courier_invoice.merge(courier_rates,left_on='zone_x',right_on='Zone',how='left')

# %%
new_data.head()
# Out:
#         AWB Code    Order ID  Charged Weight  Warehouse Pincode_x  \
# 0  1091117222124  2001806232            1.30               121003
# 1  1091117222194  2001806273            1.00               121003
# 2  1091117222931  2001806408            2.50               121003
# 3  1091117223244  2001806458            1.00               121003
# 4  1091117229345  2001807012            0.15               121003
#
#    Customer Pincode Zone_x Type of Shipment  Billing Amount (Rs.)  \
# 0            507101      d  Forward charges                 140.0
# 1            486886      d  Forward charges                 101.2
# 2            532484      d  Forward charges                 224.6
# 3            143001      b  Forward charges                  61.3
# 4            515591      d  Forward charges                  45.4
#
#    Warehouse Pincode_y zone_x Zone_y  Weight Slabs  Forward Fixed Charge  \
# 0               121003      d      d          1.25                  45.4
# ...

# %%
#now we have to get weight that we calculate earlier to be joined on this new_data table
new_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 124 entries, 0 to 123
# Data columns (total 16 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   AWB Code                               124 non-null    int64
#  1   Order ID                               124 non-null    int64
#  2   Charged Weight                         124 non-null    float64
#  3   Warehouse Pincode_x                    124 non-null    int64
#  4   Customer Pincode                       124 non-null    int64
#  5   Zone_x                                 124 non-null    object
#  6   Type of Shipment                       124 non-null    object
#  7   Billing Amount (Rs.)                   124 non-null    float64
#  8   Warehouse Pincode_y                    124 non-null    int64
#  9   zone_x                                 124 non-null    object
# ...

# %%
new_data1=new_data.merge(grouped_data,on='Order ID',how='inner')

# %%
new_data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 124 entries, 0 to 123
# Data columns (total 18 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   AWB Code                               124 non-null    int64
#  1   Order ID                               124 non-null    int64
#  2   Charged Weight                         124 non-null    float64
#  3   Warehouse Pincode_x                    124 non-null    int64
#  4   Customer Pincode                       124 non-null    int64
#  5   Zone_x                                 124 non-null    object
#  6   Type of Shipment                       124 non-null    object
#  7   Billing Amount (Rs.)                   124 non-null    float64
#  8   Warehouse Pincode_y                    124 non-null    int64
#  9   zone_x                                 124 non-null    object
# ...

# %%
new_data1.head()
# Out:
#         AWB Code    Order ID  Charged Weight  Warehouse Pincode_x  \
# 0  1091117222124  2001806232            1.30               121003
# 1  1091117222194  2001806273            1.00               121003
# 2  1091117222931  2001806408            2.50               121003
# 3  1091117223244  2001806458            1.00               121003
# 4  1091117229345  2001807012            0.15               121003
#
#    Customer Pincode Zone_x Type of Shipment  Billing Amount (Rs.)  \
# 0            507101      d  Forward charges                 140.0
# 1            486886      d  Forward charges                 101.2
# 2            532484      d  Forward charges                 224.6
# 3            143001      b  Forward charges                  61.3
# 4            515591      d  Forward charges                  45.4
#
#    Warehouse Pincode_y zone_x Zone_y  Weight Slabs  Forward Fixed Charge  \
# 0               121003      d      d          1.25                  45.4
# ...

# %%
import math

# %%
def charges(x):
  return len(x)
new_data1['Type of Shipment']=new_data1['Type of Shipment'].apply(charges)

# %%
new_data1['Type of Shipment']=new_data1['Type of Shipment'].astype(int)

# %%
# so now forward charge will be length 15 and forward and rto charges will be length 23
def calculation_price(new_data1):
  x=0
  price=0
  if new_data1['total_weight(kg)_x']>new_data1['Weight Slabs']:
    x=math.ceil(new_data1['total_weight(kg)_x']/new_data1['Weight Slabs'])
  else:
    x=1
  if new_data1['Type of Shipment']==15:
    price=new_data1['Forward Fixed Charge']+(x-1)*new_data1['Forward Additional Weight Slab Charge']
  else:
    price=new_data1['Forward Fixed Charge']+(x-1)*new_data1['Forward Additional Weight Slab Charge']+new_data1['RTO Fixed Charge']+(x-1)*new_data1['RTO Additional Weight Slab Charge']
  return price

# %%
new_data1['price_x']=new_data1.apply(calculation_price,axis=1)

# %%
new_data1
# Out:
#           AWB Code    Order ID  Charged Weight  Warehouse Pincode_x  \
# 0    1091117222124  2001806232            1.30               121003
# 1    1091117222194  2001806273            1.00               121003
# 2    1091117222931  2001806408            2.50               121003
# 3    1091117223244  2001806458            1.00               121003
# 4    1091117229345  2001807012            0.15               121003
# ..             ...         ...             ...                  ...
# 119  1091118551656  2001812941            0.73               121003
# 120  1091117614452  2001809383            0.50               121003
# 121  1091120922803  2001820978            0.50               121003
# 122  1091121844806  2001811475            0.50               121003
# 123  1091121846136  2001811305            0.50               121003
#
#      Customer Pincode Zone_x  Type of Shipment  Billing Amount (Rs.)  \
# 0              507101      d                15                 140.0
# ...

# %%
new_data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 124 entries, 0 to 123
# Data columns (total 19 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   AWB Code                               124 non-null    int64
#  1   Order ID                               124 non-null    int64
#  2   Charged Weight                         124 non-null    float64
#  3   Warehouse Pincode_x                    124 non-null    int64
#  4   Customer Pincode                       124 non-null    int64
#  5   Zone_x                                 124 non-null    object
#  6   Type of Shipment                       124 non-null    int64
#  7   Billing Amount (Rs.)                   124 non-null    float64
#  8   Warehouse Pincode_y                    124 non-null    int64
#  9   zone_x                                 124 non-null    object
# ...

# %%
#now renaming columns to as per given assignment
new_data1.rename(columns={'total_weight(kg)_x':'Total weight as per X (KG)','Weight Slabs':'Weight slab as per X (KG)','Charged Weight':'Total weight as per Courier Company (KG)','zone_x':'Delivery Zone as per X','Zone_x':'Delivery Zone charged by Courier Company','price_x':'Expected Charge as per X (Rs.)','Billing Amount (Rs.)':'Charges Billed by Courier Company (Rs.)'},inplace=True)

# %%
new_data1['Difference Between Expected Charges and Billed Charges (Rs.)']=new_data1['Expected Charge as per X (Rs.)']-new_data1['Charges Billed by Courier Company (Rs.)']

# %%
new_data1.to_excel('assignment.xlsx',index=False)

# %%
from google.colab import files
files.download('assignment.xlsx')
